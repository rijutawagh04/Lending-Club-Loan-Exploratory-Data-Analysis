# %% [markdown]
# ### Attempt to predict the interest rate charged to a group/cluster of loans.
#
# ### Loading the cleaned Accepted Loan csv file into dataframe

# %%
from scipy.cluster.vq import kmeans,vq
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pylab as pl

# %pylab inline

data_directory = os.path.join('.', 'Data') 

cleaned_accepted_data_path = os.path.join(data_directory, 'Cleaned_AcceptedLoanDataV.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
accepted_df = pd.read_csv(cleaned_accepted_data_path, low_memory=False, encoding='UTF-8')

# Temporarily sample until we have an idea of how long this will take.
accepted_df = accepted_df.sample(n=100000)

# There's a row with an income of 4.3m that is badly skewing the results, so remove it for now.
accepted_df = accepted_df[accepted_df.annual_inc < 1000000]

print(accepted_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99975 entries, 111784 to 52532
# Data columns (total 34 columns):
# Unnamed: 0                    99975 non-null int64
# loan_amnt                     99975 non-null float64
# term                          99975 non-null object
# int_rate                      99975 non-null float64
# emp_length                    99975 non-null float64
# home_ownership                99975 non-null object
# annual_inc                    99975 non-null float64
# verification_status           99975 non-null object
# issue_d                       99975 non-null object
# purpose                       99975 non-null object
# dti                           99975 non-null float64
# delinq_2yrs                   99975 non-null float64
# earliest_cr_line              99975 non-null int64
# inq_last_6mths                99975 non-null float64
# mths_since_last_delinq        99975 non-null float64
# pub_rec                       99975 non-null float64
# revol_bal                     99975 non-null float64
# revol_util                    99975 non-null float64
# total_acc                     99975 non-null float64
# collections_12_mths_ex_med    99975 non-null float64
# application_type              99975 non-null object
# verification_status_joint     99975 non-null object
# acc_open_past_24mths          99975 non-null float64
# avg_cur_bal                   99975 non-null float64
# bc_open_to_buy                99975 non-null float64
# chargeoff_within_12_mths      99975 non-null float64
# delinq_amnt                   99975 non-null float64
# mort_acc                      99975 non-null float64
# pct_tl_nvr_dlq                99975 non-null float64
# timestamp                     99975 non-null int64
# fico_range                    99975 non-null object
# mean_fico                     99975 non-null float64
# last_fico_range               99975 non-null object
# last_mean_fico                99975 non-null float64
# dtypes: float64(22), int64(3), object(9)
# memory usage: 26.7+ MB
# None

# %%
accepted_df = pd.read_csv(cleaned_accepted_data_path, low_memory=False, encoding='UTF-8')

# Temporarily sample until we have an idea of how long this will take.
accepted_df = accepted_df.sample(n=100000)

# There's a row with an income of 4.3m that is badly skewing the results, so remove it for now.
accepted_df = accepted_df[accepted_df.annual_inc < 1000000]

print(accepted_df.info())

# Remove non-numeric columns and those we don't care about.
accepted_df.drop(['Unnamed: 0', 'purpose', 'issue_d', 'fico_range', 'last_fico_range', 'timestamp'], 
                 axis=1, inplace=True)

# Remove the interest rate, since we're going to try and predict that from the clustering.
accepted_df.drop(['int_rate'], axis=1, inplace=True)

# Replace the string 'term' with a number.
accepted_df['term'].replace(to_replace='[^0-9]+', value='', inplace=True, regex=True)
accepted_df['term'] = accepted_df['term'].astype(int)

# Split home ownership values into separate variables:
# home_mortgage, home_rent and home_own.
accepted_df['home_mortgage'] = 0
accepted_df['home_rent'] = 0
accepted_df['home_own'] = 0

accepted_df.loc[accepted_df['home_ownership']=='MORTGAGE', 'home_mortgage'] = 1
accepted_df.loc[accepted_df['home_ownership']=='RENT', 'home_rent'] = 1
accepted_df.loc[accepted_df['home_ownership']=='OWN', 'home_own'] = 1

# Drop home_ownership now.
accepted_df.drop(['home_ownership'], axis=1, inplace=True)

# Split application_type into separate variables: individual (0/1)
accepted_df['individual'] = 0
accepted_df.loc[accepted_df['application_type']=='INDIVIDUAL', 'individual'] = 1

# Drop application_type now.
accepted_df.drop(['application_type'], axis=1, inplace=True)

# Turn verification status into a numeric column.
accepted_df['income_verified'] = 1
accepted_df.loc[accepted_df['verification_status']=='Not Verified', 'income_verified'] = 0

# Drop verification status now.
accepted_df.drop(['verification_status', 'verification_status_joint'], axis=1, inplace=True)

# Drop the current credit score, since it wasn't available at the time the interest rate was set.
accepted_df.drop(['last_mean_fico'], axis=1, inplace=True)

print(accepted_df.info())
accepted_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99978 entries, 120926 to 86983
# Data columns (total 34 columns):
# Unnamed: 0                    99978 non-null int64
# loan_amnt                     99978 non-null float64
# term                          99978 non-null object
# int_rate                      99978 non-null float64
# emp_length                    99978 non-null float64
# home_ownership                99978 non-null object
# annual_inc                    99978 non-null float64
# verification_status           99978 non-null object
# issue_d                       99978 non-null object
# purpose                       99978 non-null object
# dti                           99978 non-null float64
# delinq_2yrs                   99978 non-null float64
# earliest_cr_line              99978 non-null int64
# inq_last_6mths                99978 non-null float64
# mths_since_last_delinq        99978 non-null float64
# pub_rec                       99978 non-null float64
# revol_bal                     99978 non-null float64
# revol_util                    99978 non-null float64
# total_acc                     99978 non-null float64
# collections_12_mths_ex_med    99978 non-null float64
# application_type              99978 non-null object
# verification_status_joint     99978 non-null object
# acc_open_past_24mths          99978 non-null float64
# avg_cur_bal                   99978 non-null float64
# bc_open_to_buy                99978 non-null float64
# chargeoff_within_12_mths      99978 non-null float64
# delinq_amnt                   99978 non-null float64
# mort_acc                      99978 non-null float64
# pct_tl_nvr_dlq                99978 non-null float64
# timestamp                     99978 non-null int64
# fico_range                    99978 non-null object
# mean_fico                     99978 non-null float64
# last_fico_range               99978 non-null object
# last_mean_fico                99978 non-null float64
# dtypes: float64(22), int64(3), object(9)
# memory usage: 26.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99978 entries, 120926 to 86983
# Data columns (total 27 columns):
# loan_amnt                     99978 non-null float64
# term                          99978 non-null int32
# emp_length                    99978 non-null float64
# annual_inc                    99978 non-null float64
# dti                           99978 non-null float64
# delinq_2yrs                   99978 non-null float64
# earliest_cr_line              99978 non-null int64
# inq_last_6mths                99978 non-null float64
# mths_since_last_delinq        99978 non-null float64
# pub_rec                       99978 non-null float64
# revol_bal                     99978 non-null float64
# revol_util                    99978 non-null float64
# total_acc                     99978 non-null float64
# collections_12_mths_ex_med    99978 non-null float64
# acc_open_past_24mths          99978 non-null float64
# avg_cur_bal                   99978 non-null float64
# bc_open_to_buy                99978 non-null float64
# chargeoff_within_12_mths      99978 non-null float64
# delinq_amnt                   99978 non-null float64
# mort_acc                      99978 non-null float64
# pct_tl_nvr_dlq                99978 non-null float64
# mean_fico                     99978 non-null float64
# home_mortgage                 99978 non-null int64
# home_rent                     99978 non-null int64
# home_own                      99978 non-null int64
# individual                    99978 non-null int64
# income_verified               99978 non-null int64
# dtypes: float64(20), int32(1), int64(6)
# memory usage: 21.0 MB
# None
#           loan_amnt          term    emp_length     annual_inc           dti  \
# count  99978.000000  99978.000000  99978.000000   99978.000000  99978.000000
# mean   14790.851737     42.889036      5.770580   76587.306402     18.229439
# std     8648.097435     10.857220      3.726691   50243.754070      8.280656
# min      900.000000     36.000000      0.000000    4800.000000      0.000000
# 25%     8000.000000     36.000000      2.000000   46900.000000     12.070000
# 50%    13000.000000     36.000000      6.000000   65000.000000     17.750000
# 75%    20000.000000     60.000000     10.000000   92000.000000     24.070000
# max    40000.000000     60.000000     10.000000  990000.000000     46.520000
#
#         delinq_2yrs  earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# count  99978.000000      99978.000000    99978.000000            99978.000000
# mean       0.330643         18.637270        0.659135               33.862327
# std        0.891474          7.583819        0.974504               15.491826
# min        0.000000          0.000000        0.000000                0.000000
# 25%        0.000000         13.000000        0.000000               30.000000
# 50%        0.000000         17.000000        0.000000               33.849096
# 75%        0.000000         23.000000        1.000000               33.849096
# max       24.000000         66.000000       32.000000              168.000000
#
#             pub_rec       ...         chargeoff_within_12_mths   delinq_amnt  \
# count  99978.000000       ...                     99978.000000  99978.000000
# mean       0.218605       ...                         0.009073     14.121668
# std        0.688203       ...                         0.112297    733.157405
# min        0.000000       ...                         0.000000      0.000000
# 25%        0.000000       ...                         0.000000      0.000000
# 50%        0.000000       ...                         0.000000      0.000000
# 75%        0.000000       ...                         0.000000      0.000000
# max       86.000000       ...                         6.000000  97619.000000
#
#            mort_acc  pct_tl_nvr_dlq     mean_fico  home_mortgage  \
# count  99978.000000    99978.000000  99978.000000   99978.000000
# mean       1.687959       94.076111    697.032217       0.496189
# std        1.968427        8.504210     30.733841       0.499988
# min        0.000000       15.400000    622.000000       0.000000
# 25%        0.000000       91.700000    672.000000       0.000000
# 50%        1.000000       97.000000    692.000000       0.000000
# 75%        3.000000      100.000000    712.000000       1.000000
# max       35.000000      100.000000    847.500000       1.000000
#
#           home_rent      home_own    individual  income_verified
# count  99978.000000  99978.000000  99978.000000     99978.000000
# mean       0.398468      0.105163      0.992958         0.696073
# std        0.489585      0.306765      0.083618         0.459954
# min        0.000000      0.000000      0.000000         0.000000
# 25%        0.000000      0.000000      1.000000         0.000000
# 50%        0.000000      0.000000      1.000000         1.000000
# 75%        1.000000      0.000000      1.000000         1.000000
# max        1.000000      1.000000      1.000000         1.000000
#
# [8 rows x 27 columns]

# %%
#Applying algorithm which will group all nearby values together

K = range(1,10)

KM = [kmeans(accepted_df, k) for k in K] 
centroids = [cent for (cent, var) in KM]

#Calculating distance of a point from it's neighboring points and combining closer values together using euclidean distance
D_k = [cdist(accepted_df, cent, 'euclidean') for cent in centroids]

cIdx = [np.argmin(D, axis=1) for D in D_k] 
dist = [np.min(D, axis=1) for D in D_k]
avgWithinSS = [sum(d) / accepted_df.shape[0] for d in dist]

# %% [markdown]
# ### Deciding how many groups to form based on Eucledian distance

# %%
kIdx = 3

# plot elbow curve
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(K, avgWithinSS, 'b*-')
ax.plot(K[kIdx], avgWithinSS[kIdx], marker='o', markersize=12, 
      markeredgewidth=2, markeredgecolor='r', markerfacecolor='None')
plt.grid(True)
plt.xlabel('Number of groups')
plt.ylabel('Average within-group sum of squares')

# %% [markdown]
# ### This shows that we have to form 4 groups.

# %%
km = KMeans(4, init='k-means++') # initialize
km.fit(accepted_df)
accepted_df['cluster'] = km.predict(accepted_df) # classify into groups

# %% [markdown]
# ### Dividing data into 4 groups for every column in the dataframe

# %%
def plot_clusters(orig, pred, nx, ny, labels, legend=True):
    data = orig
 
    # plot data into three clusters based on value of c
    p0 = plt.plot(data[pred==0,nx], data[pred==0,ny], 'ro', label='Medium')
    p1 = plt.plot(data[pred==1,nx], data[pred==1,ny], 'bo', label='Low') 
    p2 = plt.plot(data[pred==2,nx], data[pred==2,ny], 'go', label='MedHigh') 
    p3 = plt.plot(data[pred==3,nx], data[pred==3,ny], 'yo', label='High') 


    lx = p1[0].axes.set_xlabel(labels[nx])
    ly = p1[0].axes.set_ylabel(labels[ny])
    tt= plt.title('Lending Club Dataset with 4 groups')
    
    if legend:
        ll=plt.legend()  
  
    plt.show()
    return (p0,p1,p2,p3)


for i in range(0,accepted_df.shape[1]):
    if i != 3:
        (pl0, pl1, pl2, pl3) = plot_clusters(accepted_df.values, accepted_df['cluster'].values, 
                                             3, i, accepted_df.columns)

# %% [markdown]
# ### Conclusion: There are 4 groups Medium, Low, MedHigh, High for each of the columns in the dataset. The plots above show annual income vs other features. People with annual income between ~100000 and 130000 belong to group1. People with annual income between ~140000-180000 belong to group2.  People with annual income between ~200000 and 300000 belong to group3. People with annual income > 400000 belong to group4 and are labeled as high.
#
# ### Some key observations from the above plots:
# 1. dti is less for people with high annual income.
# 2. Most number of people in the dataset have annual income >400000 and thus qualify to apply for loan
# 3. Annual income increases with increase in employment length
# 4. delinq_2yrs is lower for people with annual income>=400000 and higher for people with annual income<=300000

# %%
plt.savefig('cluster.png')
